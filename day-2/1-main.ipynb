# %%
from openai import OpenAI
from dotenv import load_dotenv
import json 

load_dotenv()
# Out:
# True

# %%
my_tools  =[
{
    "type": "function",
    "name":"get_stock_info",
    "description" :"it return the details associated with the provided stock code",
    "parameters" :    {
        "type":"object",
        "properties": { 
            "stock_code" :
                        {
                            "type":"string" , 
                            "description" : "a unique code which tell stock information for a particular stock price"
                        }

        },
        "required" :["stock_code"]

    }
}

,{
    "name":"get_schema",
    "type":"function",
    "description":"get the name of the schema of the table",
    "parameters" :{
            "type":"object",
            "properties" : {
                "table_name":{
                    "type":"string",
                    "description":"represente name of the table in question"
                }
            },
            "required":["table_name"]
                }  
}

]

# %%
client = OpenAI()
user_input ="give me stock ifnromation for INFY"

prompt='''
You are are Postgres SQL Expert 
To answer the use question , you have to think about the name of the table what could be the name of the table 
which are being asked and once figure that out then we have to find out  about schema of that corresponding table 
for that we might need to make another function call as tools are being added 

'''
response = client.responses.create(model="gpt-5.6-luna", input = user_input , tools = my_tools)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[8], line 11
#       7 which are being asked and once figure that out then we have to find out  about schema of that corresponding table
#       8 for that we might need to make another function call as tools are being added
#       9
#      10 '''
# ---> 11 response = client.responses.create(model="gpt-5.0-luna", input = user_input , tools = my_tools)
#
# ...

# %%
llm_output=response.output 
## it will be having some parts where it mght be making calls to the functions 
tools_output=[]
while True:
    pass
