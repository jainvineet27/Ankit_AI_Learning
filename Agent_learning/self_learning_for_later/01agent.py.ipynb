# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
# How to get your Databricks token: https://docs.databricks.com/en/dev-tools/auth/pat.html
#DATABRICKS_TOKEN = os.environ.get('DATABRICKS_TOKEN')
# Alternatively in a Databricks notebook you can use this:
DATABRICKS_TOKEN = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()

client = OpenAI(
    api_key=DATABRICKS_TOKEN,
    base_url="https://dbc-bc8edf8f-7367.cloud.databricks.com/serving-endpoints"
)
#3 different python classes object  uski method hai create .. ukso call kr rhe h 
## supply kia hai  model   messgae in the form of  [ {"role":"user" , "content": "capital of france "}]
## output  hai lsit  , list ka forst object ek  nest dictionay  ka message.content 
response = client.chat.completions.create(
    model="databricks-gpt-oss-120b",
    messages=[
        {
            "role": "user",
            "content": "Capital of France?"
        }
    ],
    max_tokens=5000
)

print(response.choices[0].message.content[:100])
